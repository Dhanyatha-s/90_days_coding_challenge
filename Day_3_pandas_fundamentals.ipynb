# %%
import pandas as pd

# %% [markdown]
# Day : Pandas Fundamentals
#
# project - Clean CSV data
# load Messy data
# clean: handle null values, remove duplicates, fix data types
# Export Clean versions

# %%
# Create Synthetic dataset
import pandas as pd
import numpy as np



data = {
    "id": range(1, 51),
    "name": [
        "Alice","Bob","Carla","David","Eva","Frank","Gina","Henry","Isha","John",
        "Kavya","Liam","Maya","Nina","Omar","Pranav","Queena","Rahul","Sara","Tom",
        "Usha","Varun","Will","Xena","Yash","Zara","Anil","Bhanu","Charan","Diya",
        "Elon","Farah","Gopi","Harsh","Iram","Jai","Kiran","Leela","Manoj","Niharika",
        "Oviya","Prem","Riya","Shaan","Tina","Uma","Vinay","Wasim","Xavier","Yamini"
    ],
    "age": [25, "thirty", np.nan, "40abc", 29, 44, np.nan, 33, 27, "twenty",
            24, np.nan, 31, 28, 45, "abc", 26, 30, np.nan, 35,
            22, 48, 39, 27, 33, np.nan, 29, 26, 44, 23,
            36, 31, 28, 27, np.nan, 29, 32, 30, "abc", 25,
            29, 31, 34, 40, 22, 27, 33, 28, 26, np.nan],
    
    "email": [
        "alice@example.com", "bob email@com", "carla@gmail", "david@example.com",
        "eva_stone@example.com", "frank@@mail.com", "gina@example.com", "henry@exa mple.com",
        "Isha@example.com", "john@@example.com", "kavya@example.com", "liam@example.com",
        "mayagmail.com", "nina@@gmail.com", "Omar@example.com", "pranav@example.com",
        "queena@example", "rahul example.com", "sara@mail.com", "tom@@example.com",
        "usha@example.com", "varun@company", "will@@gmail.com", "xena@examplecom",
        "yash @gmail.com", "zara@mail.com", "anil@@example.com", "bhanu.com",
        "charan@example", "diya@@gmail.com", "elonmail.com", "farah@ company.com",
        "gopi@examplecom", "harsh@@gmail.com", "iramexample.com", "jai @gmail.com",
        "kiran@@mail.com", "leela@gmail", "manoj@mail.com", "niharika@@gmail.com",
        "oviya@company.com", "prem @mail.com", "riyagmail.com", "shaan@@gmail.com",
        "tina@example.com", "uma@@example.com", "vinaymail.com", "wasim@@gmail.com",
        "xavier @mail.com", "yamini@mail.com"
    ],

    "city": [
        "Bangalore", "Mumbai", "Delhi", "Banglore", "Chennai", "Hyderabad", "Bengaluru","Pune",
        "Bangalore","Delhi","Mumbai","Chennai","Bangalore","Hyderabad","Pune","Pune","Bangaluru",
        "Chennai","Hyderabad","Bangalore","Mumbai","Delhi","Pune","Chennai","Bengaluru","Hyderabad",
        "Bangalore","Mumbai","Pune","Chennai","Hyderabad","Bangalore","Mumbai","Delhi","Pune",
        "Banglore","Chennai","Bangalore","Hyderabad","Pune","Mumbai","Delhi","Pune","Hyderabad",
        "Chennai","Bangalore","Delhi","Pune","Bengaluru","Bangalore"
    ],

    "salary": [
        45000, 52000, np.nan, 60000, 55000, 70000, 62000, 58000, np.nan, 50000,
        48000, 54000, 61000, 57000, 68000, 62000, 59000, 61000, 55000, np.nan,
        48000, 60000, 53000, np.nan, 56000, 62000, 51000, 48000, 70000, 45000,
        90000, 55000, np.nan, 53000, 58000, 56000, 61000, 54000, 50000, 48000,
        68000, 61000, 62000, np.nan, 46000, 57000, 58000, 55000, 54000, 50000
    ],
    
    "join_date": [
        "2021-05-10","2020/13/05","2020-07-20","18-05-2019","2021-09-30","2021/05/11",
        "2020-11-20","2021-08-25","2020/07/19","2019-05-32","2021-13-05","2020/02/20",
        "2019-05-10","2022/07/12","2020-09-20","2021/05/11","2021-08-11","2019-19-05",
        "2020-06-31","2021/07/20","2021-05-10","2020/02/30","2019-07-10","2020-05-10",
        "2021/11/12","2020-06-20","2021-08-21","2021/12/10","2019-13-05","2020/05/10",
        "2021-07-11","2020/11/10","2019-05-10","2021/02/20","2020-07-15","2020/08/10",
        "2021-05-31","2021/06/20","2020-10-10","2019/05/10","2020-13-10","2021/05/12",
        "2019-08-10","2021/02/20","2020-07-17","2021/06/18","2019-10-10","2020/03/19",
        "2021-07-30","2020-05-12"
    ]
}

df = pd.DataFrame(data)



df.to_csv("simple_dirty_dataset.csv", index=False)

print("CSV Created: simple_dirty_dataset.csv")
# Out:
# CSV Created: simple_dirty_dataset.csv

# %%
df.describe()
# Out:
#              id        salary
# count  50.00000     44.000000
# mean   25.50000  56954.545455
# std    14.57738   8178.117556
# min     1.00000  45000.000000
# 25%    13.25000  51750.000000
# 50%    25.50000  56000.000000
# 75%    37.75000  61000.000000
# max    50.00000  90000.000000

# %%
df.isnull().sum()
# Out:
# id           0
# name         0
# age          7
# email        0
# city         0
# salary       6
# join_date    0
# dtype: int64

# %%
df['age']
# Out:
# 0         25
# 1     thirty
# 2        NaN
# 3      40abc
# 4         29
# 5         44
# 6        NaN
# 7         33
# 8         27
# 9     twenty
# 10        24
# 11       NaN
# 12        31
# 13        28
# 14        45
# 15       abc
# 16        26
# 17        30
# 18       NaN
# 19        35
# 20        22
# 21        48
# 22        39
# 23        27
# 24        33
# 25       NaN
# 26        29
# 27        26
# 28        44
# 29        23
# 30        36
# 31        31
# 32        28
# 33        27
# 34       NaN
# 35        29
# 36        32
# 37        30
# 38       abc
# 39        25
# 40        29
# 41        31
# 42        34
# 43        40
# 44        22
# 45        27
# 46        33
# 47        28
# 48        26
# 49       NaN
# Name: age, dtype: object

# %% [markdown]
# There are things to notice here we have a two types of values string and integer, along with it we also have some of the NAN value its basically null values we can replace it with either 0 or string "Unknown"

# %%
# First thing replace NAN with Unknown
df["age"] = df["age"].fillna("Unknown")
df["age"]
# Out:
# 0          25
# 1      thirty
# 2     Unknown
# 3       40abc
# 4          29
# 5          44
# 6     Unknown
# 7          33
# 8          27
# 9      twenty
# 10         24
# 11    Unknown
# 12         31
# 13         28
# 14         45
# 15        abc
# 16         26
# 17         30
# 18    Unknown
# 19         35
# 20         22
# 21         48
# 22         39
# 23         27
# 24         33
# 25    Unknown
# 26         29
# 27         26
# 28         44
# 29         23
# 30         36
# 31         31
# 32         28
# 33         27
# 34    Unknown
# 35         29
# 36         32
# 37         30
# 38        abc
# 39         25
# 40         29
# 41         31
# 42         34
# 43         40
# 44         22
# 45         27
# 46         33
# 47         28
# 48         26
# 49    Unknown
# Name: age, dtype: object

# %%
# Now lets get them to be numeric values
df["age"] = pd.to_numeric(df["age"], errors="coerce") #invalid parsing will be replaced to NAN

# %%
# now lets  have a look i guess i made mistake
df["age"]
# Out:
# 0     25.0
# 1      NaN
# 2      NaN
# 3      NaN
# 4     29.0
# 5     44.0
# 6      NaN
# 7     33.0
# 8     27.0
# 9      NaN
# 10    24.0
# 11     NaN
# 12    31.0
# 13    28.0
# 14    45.0
# 15     NaN
# 16    26.0
# 17    30.0
# 18     NaN
# 19    35.0
# 20    22.0
# 21    48.0
# 22    39.0
# 23    27.0
# 24    33.0
# 25     NaN
# 26    29.0
# 27    26.0
# 28    44.0
# 29    23.0
# 30    36.0
# 31    31.0
# 32    28.0
# 33    27.0
# 34     NaN
# 35    29.0
# 36    32.0
# 37    30.0
# 38     NaN
# 39    25.0
# 40    29.0
# 41    31.0
# 42    34.0
# 43    40.0
# 44    22.0
# 45    27.0
# 46    33.0
# 47    28.0
# 48    26.0
# 49     NaN
# Name: age, dtype: float64

# %%
# The mistake was i filled NAN value with "Unknown" before having data in numeric form so it used "coerce" well
df["age"] = df["age"].fillna("Unknown")

# %%
df["age"]
# Out:
# 0        25.0
# 1     Unknown
# 2     Unknown
# 3     Unknown
# 4        29.0
# 5        44.0
# 6     Unknown
# 7        33.0
# 8        27.0
# 9     Unknown
# 10       24.0
# 11    Unknown
# 12       31.0
# 13       28.0
# 14       45.0
# 15    Unknown
# 16       26.0
# 17       30.0
# 18    Unknown
# 19       35.0
# 20       22.0
# 21       48.0
# 22       39.0
# 23       27.0
# 24       33.0
# 25    Unknown
# 26       29.0
# 27       26.0
# 28       44.0
# 29       23.0
# 30       36.0
# 31       31.0
# 32       28.0
# 33       27.0
# 34    Unknown
# 35       29.0
# 36       32.0
# 37       30.0
# 38    Unknown
# 39       25.0
# 40       29.0
# 41       31.0
# 42       34.0
# 43       40.0
# 44       22.0
# 45       27.0
# 46       33.0
# 47       28.0
# 48       26.0
# 49    Unknown
# Name: age, dtype: object

# %%
# lest see does age col has handled well or not
df["age"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 50 entries, 0 to 49
# Series name: age
# Non-Null Count  Dtype
# --------------  -----
# 50 non-null     object
# dtypes: object(1)
# memory usage: 532.0+ bytes

# %% [markdown]
# Same way we have dirty reads on Salary col too lets handle it

# %%
df["salary"]
# Out:
# 0     45000.0
# 1     52000.0
# 2         NaN
# 3     60000.0
# 4     55000.0
# 5     70000.0
# 6     62000.0
# 7     58000.0
# 8         NaN
# 9     50000.0
# 10    48000.0
# 11    54000.0
# 12    61000.0
# 13    57000.0
# 14    68000.0
# 15    62000.0
# 16    59000.0
# 17    61000.0
# 18    55000.0
# 19        NaN
# 20    48000.0
# 21    60000.0
# 22    53000.0
# 23        NaN
# 24    56000.0
# 25    62000.0
# 26    51000.0
# 27    48000.0
# 28    70000.0
# 29    45000.0
# 30    90000.0
# 31    55000.0
# 32        NaN
# 33    53000.0
# 34    58000.0
# 35    56000.0
# 36    61000.0
# 37    54000.0
# 38    50000.0
# 39    48000.0
# 40    68000.0
# 41    61000.0
# 42    62000.0
# 43        NaN
# 44    46000.0
# 45    57000.0
# 46    58000.0
# 47    55000.0
# 48    54000.0
# 49    50000.0
# Name: salary, dtype: float64

# %%
# So we just have null values here
df["salary"] = df["salary"].fillna(0)

# %%
df["salary"]
# Out:
# 0     45000.0
# 1     52000.0
# 2         0.0
# 3     60000.0
# 4     55000.0
# 5     70000.0
# 6     62000.0
# 7     58000.0
# 8         0.0
# 9     50000.0
# 10    48000.0
# 11    54000.0
# 12    61000.0
# 13    57000.0
# 14    68000.0
# 15    62000.0
# 16    59000.0
# 17    61000.0
# 18    55000.0
# 19        0.0
# 20    48000.0
# 21    60000.0
# 22    53000.0
# 23        0.0
# 24    56000.0
# 25    62000.0
# 26    51000.0
# 27    48000.0
# 28    70000.0
# 29    45000.0
# 30    90000.0
# 31    55000.0
# 32        0.0
# 33    53000.0
# 34    58000.0
# 35    56000.0
# 36    61000.0
# 37    54000.0
# 38    50000.0
# 39    48000.0
# 40    68000.0
# 41    61000.0
# 42    62000.0
# 43        0.0
# 44    46000.0
# 45    57000.0
# 46    58000.0
# 47    55000.0
# 48    54000.0
# 49    50000.0
# Name: salary, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         50 non-null     int64
#  1   name       50 non-null     object
#  2   age        50 non-null     object
#  3   email      50 non-null     object
#  4   city       50 non-null     object
#  5   salary     50 non-null     float64
#  6   join_date  50 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.9+ KB

# %%
df_new = df

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         50 non-null     int64
#  1   name       50 non-null     object
#  2   age        50 non-null     object
#  3   email      50 non-null     object
#  4   city       50 non-null     object
#  5   salary     50 non-null     float64
#  6   join_date  50 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.9+ KB

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#
